# %%
import os
import gmsh

# %%
pwd
# Out:
# 'C:\\Users\\shafi\\Desktop\\PERF-METRICS_GEOS_SIMS\\SIMULATION_SOME_LLMS_REDONE\\BAR\\GPT_4'

# %%
PROJECT_NAME = 'square_bar'

# %%
def generate_ELMER_mesh():
    try:
        current_directory = os.getcwd()
        msh_file = os.path.join(current_directory, f'{PROJECT_NAME}.msh')  
        !"C:\Program Files\ElmerFEM-gui-nompi-Windows-AMD64\bin\ElmerGrid.exe" 14 2 "{msh_file}" 
        print(f"ELMER project created in {PROJECT_NAME}")
        print(f"Copy .sif file in {PROJECT_NAME}")
    except ValueError as e:
        print(f"ERROR.")

# %%
generate_ELMER_mesh()
# Out:
# ELMER project created in square_bar
# Copy .sif file in square_bar
#
# Starting program Elmergrid, compiled on Apr 16 2025
# Elmergrid reading in-line arguments
# Output will be saved to file C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar.
#
# Elmergrid loading data:
# -----------------------
# Format chosen using the first line: $MeshFormat
# Gmsh input file format is type   4.1 in ASCII.
# Loading mesh in Gmsh format 4.1 from file C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar.msh
# Reading 8 entities in 0D
# Reading 12 entities in 1D
# Reading 6 entities in 2D
# Reading 1 entities in 3D
# Allocating for 10250 knots and 57462 elements.
# Leading element dimension is 3
# BC name for physical group 1 is: Bottom
# BC name for physical group 2 is: Top
# BC name for physical group 3 is: Front
# BC name for physical group 4 is: Right
# BC name for physical group 5 is: Back
# BC name for physical group 6 is: Left
# Body name for physical group 7 is: Bar
# Allocating lookup table for tags of size 12
# Defined 8 0DIM entities with geometric tag range [1 8]
# Defined 12 1DIM entities with geometric tag range [1 12]
# Defined 6 2DIM entities with geometric tag range [1 6]
#    Physical given tag range is [1 6]
# Defined 1 3DIM entities with geometric tag range [1 1]
#    Physical given tag range is [7 7]
# Physical tag offset for 1D is 6
# Physical tag offset for 0D is 6
# Geometric tag offset for 1D is 12
# Geometric tag offset for 0D is 24
# Reading 10250 nodes in 27 blocks.
# Reading 57462 elements in 7 blocks.
# Mapping mesh tag 1 to physical tag 1 in 2DIM
# Mapping mesh tag 2 to physical tag 2 in 2DIM
# Mapping mesh tag 3 to physical tag 3 in 2DIM
# Mapping mesh tag 4 to physical tag 4 in 2DIM
# Mapping mesh tag 5 to physical tag 5 in 2DIM
# Mapping mesh tag 6 to physical tag 6 in 2DIM
# Mapping mesh tag 1 to physical tag 7 in 3DIM
# Moving bulk elements to boundary elements
# Assuming that boundaries names are already Ok!
# Leading bulk elementtype is 504
# Trailing bulk elementtype is 303
# There are 10062 (out of 57462) lower dimensional elements.
# Node 6286 belongs to maximum of 42 elements
# Found correctly 10062 side elements.
# Parent elements were reordered up to index 47400.
# Moved 47400 elements (out of 57462) to new positions
# Successfully read the mesh from the Gmsh input file C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar.msh
# Using physical numbering of entities
#
# Elmergrid creating and manipulating meshes:
# -------------------------------------------
# Bounding box of all nodes in mesh:
# X:[0,1] Y:[0,1] Z:[0,10]
# Calculate Mesh Pieces in mesh:
# There is a single piece in the mesh, so the mesh is conforming.
#
# Elmergrid saving data with method 2:
# -------------------------------------
# Saving mesh in ElmerSolver format to directory C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar.
# Saving 10250 coordinates to mesh.nodes.
# Saving 47400 element topologies to mesh.elements.
# Saving boundary elements to mesh.boundary.
# Saving header info to mesh.header.
# Saving names info to mesh.names.
# Saving entities info to entities.sif.
#
# Thank you for using Elmergrid!
# Send bug reports and feature wishes to elmeradm@csc.fi

# %%
gmsh.initialize()
gmsh.open(f"{PROJECT_NAME}.msh")
physical_groups = gmsh.model.getPhysicalGroups()
print("Physical groups in the mesh:")
for group in physical_groups:
    dim, tag = group
    name = gmsh.model.getPhysicalName(dim, tag)
    if name == "":
        name = f"No name (tag {tag})"
    print(f"Dimension {dim}, Tag {tag}, Name: {name}")
gmsh.finalize()
# Out:
# Physical groups in the mesh:
# Dimension 2, Tag 1, Name: Bottom
# Dimension 2, Tag 2, Name: Top
# Dimension 2, Tag 3, Name: Front
# Dimension 2, Tag 4, Name: Right
# Dimension 2, Tag 5, Name: Back
# Dimension 2, Tag 6, Name: Left
# Dimension 3, Tag 7, Name: Bar

# %%
!"C:\Program Files\ElmerFEM-gui-nompi-Windows-AMD64\bin\ElmerSolver.exe" "C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar_gpt_4.sif"
# Out:
# ELMER SOLVER (v 9.0) STARTED AT: 2025/05/27 01:04:27
# ParCommInit:  Initialize #PEs:            1
# MAIN:
# MAIN: =============================================================
# MAIN: ElmerSolver finite element software, Welcome!
# MAIN: This program is free software licensed under (L)GPL
# MAIN: Copyright 1st April 1995 - , CSC - IT Center for Science Ltd.
# MAIN: Webpage http://www.csc.fi/elmer, Email elmeradm@csc.fi
# MAIN: Version: 9.0 (Rev: Release, Compiled: 2025-04-16)
# MAIN:  Running one task without MPI parallelization.
# MAIN:  Running with just one thread per task.
# MAIN:  Lua interpreter linked in.
# MAIN: =============================================================
# MAIN:
# MAIN:
# MAIN: -------------------------------------
# MAIN: Reading Model: C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar_gpt_4.sif
#  Caught LUA error:[string "loadfile("C:/Program Files (x86)/Elmer/shar..."]:1: attempt to call a nil value
#  Caught LUA error:[string "loadstring(readsif("C:\Users\shafi\Desktop\..."]:1: attempt to call global 'readsif' (a nil value)
# LoadInputFile: Scanning input file: C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar_gpt_4.sif
# LoadInputFile: Scanning only size info
# LoadInputFile: First time visiting
# LoadInputFile: Reading base load of sif file
# LoadInputFile: Loading input file: C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\BAR\GPT_4\square_bar_gpt_4.sif
# LoadInputFile: Reading base load of sif file
# LoadInputFile: Number of BCs: 2
# LoadInputFile: Number of Body Forces: 0
# LoadInputFile: Number of Initial Conditions: 1
# LoadInputFile: Number of Materials: 1
# LoadInputFile: Number of Equations: 1
# LoadInputFile: Number of Solvers: 1
# LoadInputFile: Number of Bodies: 1
# ListTagKeywords: Setting weight for keywords!
# ListTagKeywords: No parameters width suffix: normalize by area
# ListTagKeywords: Setting weight for keywords!
# ListTagKeywords: No parameters width suffix: normalize by volume
#       10 0.5551E+00
#       20 0.5541E+00
#       30 0.5573E+00
#       40 0.4307E+00
#       50 0.3583E+00
#       60 0.3478E+00
#       70 0.3538E+00
#       80 0.2742E+00
#       90 0.3024E+00
#      100 0.3002E+00
#      110 0.2977E+00
#      120 0.2732E+00
#      130 0.1675E+00
#      140 0.8188E-01
#      150 0.7890E-01
#      160 0.6193E-01
#      170 0.3648E+00
#      180 0.3243E-01
#      190 0.3531E-01
#      200 0.2359E-01
#      210 0.1185E-01
#      220 0.2568E-01
#      230 0.1693E-01
#      240 0.3359E-02
#      250 0.2831E-02
#      260 0.1103E-02
#      270 0.7936E-03
#      280 0.7739E-03
#      290 0.7562E-03
#      300 0.7351E-03
#      310 0.7012E-03
#      320 0.1162E-02
#      330 0.5896E-03
#      340 0.5847E-03
#      350 0.5845E-03
#      360 0.5835E-03
#      370 0.5830E-03
#      380 0.5818E-03
#      390 0.5836E-03
#      400 0.5894E-03
#      410 0.5865E-03
#      420 0.1853E-04
#      430 0.1134E-03
#      440 0.1140E-04
#      450 0.4883E-03
#      460 0.1947E-03
#      470 0.3002E-04
#      480 0.2598E-04
#      490 0.6409E-05
#      500 0.1034E-04
#      501 0.1034E-04
#       10 0.1833E-04
#       20 0.1107E-04
#       30 0.2078E-05
#       40 0.5630E-07
#       50 0.8426E-07
#       60 0.5211E-07
#       70 0.4564E-07
#       80 0.4260E-07
#       90 0.4094E-07
#      100 0.3796E-07
#      110 0.3888E-07
#      120 0.3999E-07
#      130 0.3433E-07
#      140 0.1821E-06
#      150 0.2783E-07
#      160 0.2783E-07
#      170 0.2792E-07
#      180 0.2763E-07
#      190 0.2741E-07
#      200 0.2739E-07
#      210 0.2736E-07
#      220 0.2761E-07
#      230 0.2732E-07
#      240 0.2732E-07
#      250 0.2727E-07
#      260 0.2717E-07
#      270 0.2705E-07
#      280 0.2705E-07
#      290 0.2775E-07
#      300 0.2878E-07
#      310 0.2565E-07
#      320 0.3161E-07
#      330 0.2652E-07
#      340 0.2725E-07
#      350 0.2545E-07
#      360 0.2572E-07
#      370 0.2467E-07
#      380 0.2161E-07
#      390 0.1974E-07
#      400 0.1118E-07
#      410 0.3145E-08
#      420 0.1123E-07
#      430 0.1181E-07
#      440 0.5046E-08
#      450 0.2772E-08
#      460 0.3481E-08
#      470 0.1380E-08
#      480 0.9586E-09
#      490 0.9668E-09
#      500 0.9916E-09
#      501 0.9916E-09
#       10 0.1210E-08
#       20 0.5685E-09
#       30 0.4744E-09
#       40 0.6647E-09
#       50 0.5300E-09
#       60 0.9145E-09
#       70 0.4962E-08
#       80 0.4161E-09
#       90 0.4506E-09
#      100 0.4581E-09
#      110 0.4747E-09
#      120 0.4878E-09
#      130 0.5054E-09
#      140 0.5252E-09
#      150 0.5415E-09
#      160 0.5572E-09
#      170 0.5715E-09
#      180 0.5930E-09
#      190 0.6115E-09
#      200 0.6207E-09
#      210 0.6252E-09
#      220 0.6317E-09
#      230 0.6354E-09
#      240 0.6388E-09
#      250 0.6382E-09
#      260 0.6391E-09
#      270 0.6440E-09
#      280 0.6475E-09
#      290 0.6489E-09
#      300 0.6526E-09
#      310 0.6498E-09
#      320 0.6492E-09
#      330 0.6497E-09
#      340 0.6497E-09
#      350 0.6496E-09
#      360 0.6496E-09
#      370 0.6496E-09
#      380 0.6497E-09
#      390 0.6506E-09
#      400 0.6513E-09
#      410 0.6513E-09
#      420 0.6513E-09
#      430 0.6564E-09
#      440 0.6585E-09
#      450 0.6617E-09
#      460 0.6643E-09
#      470 0.6755E-09
#      480 0.6799E-09
#      490 0.6838E-09
#      500 0.6944E-09
#      501 0.6944E-09
# SOLVER TOTAL TIME(CPU,REAL):        27.18       27.18
# ELMER SOLVER FINISHED AT: 2025/05/27 01:04:54
