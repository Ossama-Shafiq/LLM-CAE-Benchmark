# %%
import os 
import gmsh

# %%
pwd
# Out:
# 'C:\\Users\\shafi\\Desktop\\PERF-METRICS_GEOS_SIMS\\SIMULATION_SOME_LLMS_REDONE\\GPT_35'

# %%
PROJECT_NAME = 'wheel_axle'

# %%
def generate_ELMER_mesh():
    try:
        current_directory = os.getcwd()
        msh_file = os.path.join(current_directory, f'{PROJECT_NAME}.msh')  
        !"C:\Program Files\ElmerFEM-gui-nompi-Windows-AMD64\bin\ElmerGrid.exe" 14 2 "{msh_file}" 
        print(f"ELMER project created in {PROJECT_NAME}")
        print(f"Copy .sif file in {PROJECT_NAME}")
    except ValueError as e:
        print(f"ERROR.")

# %%
generate_ELMER_mesh()
# Out:
# Starting program Elmergrid, compiled on Apr 16 2025
# Elmergrid reading in-line arguments
# Output will be saved to file C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.
#
# Elmergrid loading data:
# -----------------------
# Format chosen using the first line: $MeshFormat
# Gmsh input file format is type   4.1 in ASCII.
# Loading mesh in Gmsh format 4.1 from file C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.msh
# Reading 6 entities in 0D
# Reading 9 entities in 1D
# Reading 7 entities in 2D
# Reading 1 entities in 3D
# Allocating for 6455 knots and 30272 elements.
# Leading element dimension is 3
# BC name for physical group 2 is: Top
# BC name for physical group 3 is: Bottom
# Body name for physical group 1 is: MainBody
# Allocating lookup table for tags of size 9
# Defined 6 0DIM entities with geometric tag range [1 6]
# Defined 9 1DIM entities with geometric tag range [1 9]
# Defined 7 2DIM entities with geometric tag range [1 7]
#    Physical given tag range is [2 3]
# Defined 1 3DIM entities with geometric tag range [1 1]
#    Physical given tag range is [1 1]
# Physical tag offset for 1D is 3
# Physical tag offset for 0D is 3
# Geometric tag offset for 1D is 10
# Geometric tag offset for 0D is 19
# Reading 6455 nodes in 23 blocks.
# Reading 30272 elements in 3 blocks.
# Mapping mesh tag 2 to physical tag 3 in 2DIM
# Mapping mesh tag 7 to physical tag 2 in 2DIM
# Mapping mesh tag 1 to physical tag 1 in 3DIM
# Moving bulk elements to boundary elements
# Assuming that boundaries names are already Ok!
# Leading bulk elementtype is 504
# Trailing bulk elementtype is 303
# There are 1024 (out of 30272) lower dimensional elements.
# Node 3018 belongs to maximum of 38 elements
# Found correctly 1024 side elements.
# Parent elements were reordered up to index 29248.
# Moved 29248 elements (out of 30272) to new positions
# Successfully read the mesh from the Gmsh input file C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.msh
# Using physical numbering of entities
#
# Elmergrid creating and manipulating meshes:
# -------------------------------------------
# Bounding box of all nodes in mesh:
# X:[-5,5] Y:[-5,5] Z:[-12,12]
# Calculate Mesh Pieces in mesh:
# There is a single piece in the mesh, so the mesh is conforming.
#
# Elmergrid saving data with method 2:
# -------------------------------------
# Saving mesh in ElmerSolver format to directory C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.
# Saving 6455 coordinates to mesh.nodes.
# Saving 29248 element topologies to mesh.elements.
# Saving boundary elements to mesh.boundary.
# Saving header info to mesh.header.
# Saving names info to mesh.names.
# Saving entities info to entities.sif.
#
# Thank you for using Elmergrid!
# Send bug reports and feature wishes to elmeradm@csc.fi
# ELMER project created in wheel_axle
# Copy .sif file in wheel_axle

# %%
gmsh.initialize()
gmsh.open(f"{PROJECT_NAME}.msh")
physical_groups = gmsh.model.getPhysicalGroups()
print("Physical groups in the mesh:")
for group in physical_groups:
    dim, tag = group
    name = gmsh.model.getPhysicalName(dim, tag)
    if name == "":
        name = f"No name (tag {tag})"
    print(f"Dimension {dim}, Tag {tag}, Name: {name}")
gmsh.finalize()
# Out:
# Physical groups in the mesh:
# Dimension 2, Tag 2, Name: Top
# Dimension 2, Tag 3, Name: Bottom
# Dimension 3, Tag 1, Name: MainBody

# %%
!"C:\Program Files\ElmerFEM-gui-nompi-Windows-AMD64\bin\ElmerSolver.exe" "C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.sif"
# Out:
# ELMER SOLVER (v 9.0) STARTED AT: 2025/05/26 22:53:44
# ParCommInit:  Initialize #PEs:            1
# MAIN:
# MAIN: =============================================================
# MAIN: ElmerSolver finite element software, Welcome!
# MAIN: This program is free software licensed under (L)GPL
# MAIN: Copyright 1st April 1995 - , CSC - IT Center for Science Ltd.
# MAIN: Webpage http://www.csc.fi/elmer, Email elmeradm@csc.fi
# MAIN: Version: 9.0 (Rev: Release, Compiled: 2025-04-16)
# MAIN:  Running one task without MPI parallelization.
# MAIN:  Running with just one thread per task.
# MAIN:  Lua interpreter linked in.
# MAIN: =============================================================
# MAIN:
# MAIN:
# MAIN: -------------------------------------
# MAIN: Reading Model: C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.sif
#  Caught LUA error:[string "loadfile("C:/Program Files (x86)/Elmer/shar..."]:1: attempt to call a nil value
#  Caught LUA error:[string "loadstring(readsif("C:\Users\shafi\Desktop\..."]:1: attempt to call global 'readsif' (a nil value)
# LoadInputFile: Scanning input file: C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.sif
# LoadInputFile: Scanning only size info
# LoadInputFile: First time visiting
# LoadInputFile: Reading base load of sif file
# LoadInputFile: Loading input file: C:\Users\shafi\Desktop\PERF-METRICS_GEOS_SIMS\SIMULATION_SOME_LLMS_REDONE\GPT_35\wheel_axle.sif
# LoadInputFile: Reading base load of sif file
# LoadInputFile: Number of BCs: 2
# LoadInputFile: Number of Body Forces: 0
# LoadInputFile: Number of Initial Conditions: 1
# LoadInputFile: Number of Materials: 1
# LoadInputFile: Number of Equations: 1
# LoadInputFile: Number of Solvers: 1
# LoadInputFile: Number of Bodies: 1
# ListTagKeywords: Setting weight for keywords!
# ListTagKeywords: No parameters width suffix: normalize by area
# ListTagKeywords: Setting weight for keywords!
# ListTagKeywords: No parameters width suffix: normalize by volume
#       10 0.9382E+00
#       20 0.4957E+00
#       30 0.8238E-01
#       40 0.3928E-01
#       50 0.1662E-01
#       60 0.1789E-01
#       70 0.6175E-02
#       80 0.4612E-02
#       90 0.3917E-02
#      100 0.3839E-02
#      110 0.2878E-01
#      120 0.3368E-02
#      130 0.2190E-02
#      140 0.1985E-02
#      150 0.1828E-02
#      160 0.1368E-02
#      170 0.7475E-03
#      180 0.3884E-03
#      190 0.4052E-03
#      200 0.2399E-03
#      210 0.3398E-03
#      220 0.1384E-02
#      230 0.3066E-02
#      240 0.2949E-02
#      250 0.2943E-02
#      260 0.2846E-02
#      270 0.3653E-02
#      280 0.3271E-02
#      290 0.4058E-02
#      300 0.3966E-02
#      310 0.3906E-02
#      320 0.4090E-02
#      330 0.3584E-02
#      340 0.3634E-02
#      350 0.3493E-02
#      360 0.4843E-02
#      370 0.5089E-02
#      380 0.4647E-02
#      390 0.2276E+00
#      400 0.1007E-02
#      410 0.1272E-02
#      420 0.1580E-04
#      430 0.1482E-05
#      440 0.2388E-05
#      450 0.1462E-05
#      460 0.1574E-05
#      470 0.1595E-05
#      480 0.1596E-05
#      490 0.1594E-05
#      500 0.1598E-05
#      501 0.1598E-05
#       10 0.4604E-05
#       20 0.4395E-05
#       30 0.2105E-05
#       40 0.2345E-05
#       50 0.2332E-05
#       60 0.2328E-05
#       70 0.2316E-05
#       80 0.2336E-05
#       90 0.2272E-05
#      100 0.2348E-05
#      110 0.2323E-05
#      120 0.2324E-05
#      130 0.2325E-05
#      140 0.2332E-05
#      150 0.5376E-05
#      160 0.2103E-05
#      170 0.2469E-05
#      180 0.6203E-05
#      190 0.5416E-05
#      200 0.3737E-05
#      210 0.5642E-05
#      220 0.2397E-05
#      230 0.2837E-05
#      240 0.2878E-05
#      250 0.2992E-05
#      260 0.3139E-05
#      270 0.3258E-05
#      280 0.3162E-05
#      290 0.2516E-05
#      300 0.2545E-05
#      310 0.2330E-05
#      320 0.5113E-05
#      330 0.1598E-05
#      340 0.1055E-05
#      350 0.1183E-05
#      360 0.1165E-05
#      370 0.1182E-05
#      380 0.5484E-06
#      390 0.4701E-06
#      400 0.5106E-06
#      410 0.4308E-06
#      420 0.2801E-06
#      430 0.3153E-06
#      440 0.8037E-08
#      450 0.7551E-08
#      460 0.7487E-08
#      470 0.7579E-08
#      480 0.7528E-08
#      490 0.7421E-08
#      500 0.7522E-08
#      501 0.7522E-08
#       10 0.2170E-07
#       20 0.2043E-07
#       30 0.1689E-07
#       40 0.1295E-07
#       50 0.1473E-07
#       60 0.1698E-07
#       70 0.1705E-07
#       80 0.1703E-07
#       90 0.1996E-07
#      100 0.1553E-07
#      110 0.1538E-07
#      120 0.1518E-07
#      130 0.1504E-07
#      140 0.3817E-07
#      150 0.6076E-08
#      160 0.5308E-08
#      170 0.5608E-08
#      180 0.5749E-08
#      190 0.5415E-08
#      200 0.5963E-08
#      210 0.5073E-08
#      220 0.5168E-08
#      230 0.4995E-08
#      240 0.5059E-08
#      250 0.5064E-08
#      260 0.5057E-08
#      270 0.5057E-08
#      280 0.5047E-08
#      290 0.5053E-08
#      300 0.5004E-08
#      310 0.5003E-08
#      320 0.4982E-08
#      330 0.4970E-08
#      340 0.4967E-08
#      350 0.4965E-08
#      360 0.4957E-08
#      370 0.4956E-08
#      380 0.4956E-08
#      390 0.4951E-08
#      400 0.4950E-08
#      410 0.4949E-08
#      420 0.4937E-08
#      430 0.4852E-08
#      440 0.4869E-08
#      450 0.4872E-08
#      460 0.4866E-08
#      470 0.4978E-08
#      480 0.4839E-08
#      490 0.4799E-08
#      500 0.5970E-07
#      501 0.5970E-07
#       10 0.8053E-07
#       20 0.9580E-07
#       30 0.9658E-07
#       40 0.8247E-07
#       50 0.1080E-06
#       60 0.3275E-07
#       70 0.2256E-07
#       80 0.2296E-07
#       90 0.1676E-07
#      100 0.1535E-07
#      110 0.9438E-08
#      120 0.9047E-08
#      130 0.8971E-08
#      140 0.1152E-07
#      150 0.8923E-08
#      160 0.8878E-08
#      170 0.8879E-08
#      180 0.9119E-08
#      190 0.1705E-07
#      200 0.9655E-08
#      210 0.7383E-08
#      220 0.3240E-08
#      230 0.3322E-08
#      240 0.3276E-08
#      250 0.3252E-08
#      260 0.3243E-08
#      270 0.3242E-08
#      280 0.3241E-08
#      290 0.1923E-07
#      300 0.2300E-08
#      310 0.3398E-08
#      320 0.3534E-08
#      330 0.3730E-08
#      340 0.6808E-09
#      350 0.1674E-08
#      359 0.3525E-10
#        1 0.3258E-10
# SOLVER TOTAL TIME(CPU,REAL):        20.38       20.38
# ELMER SOLVER FINISHED AT: 2025/05/26 22:54:04
